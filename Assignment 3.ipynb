# %%
import pandas as pd
import numpy as np
df = pd.read_csv('iris.csv')
loan = pd.read_csv('credit_test.csv')

# %%
df
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
df.dtypes
# Out:
# sepal_length    float64
# sepal_width     float64
# petal_length    float64
# petal_width     float64
# species          object
# dtype: object

# %%
df.isnull()
# Out:
#      sepal_length  sepal_width  petal_length  petal_width  species
# 0           False        False         False        False    False
# 1           False        False         False        False    False
# 2           False        False         False        False    False
# 3           False        False         False        False    False
# 4           False        False         False        False    False
# ..            ...          ...           ...          ...      ...
# 145         False        False         False        False    False
# 146         False        False         False        False    False
# 147         False        False         False        False    False
# 148         False        False         False        False    False
# 149         False        False         False        False    False
#
# [150 rows x 5 columns]

# %%
df.isnull().sum()
# Out:
# sepal_length    0
# sepal_width     0
# petal_length    0
# petal_width     0
# species         0
# dtype: int64

# %%
grouped_agg = df.groupby('species').agg({'sepal_length':['mean','median','max','min','std']})

# %%
grouped_agg
# Out:
#            sepal_length
#                    mean median  max  min       std
# species
# setosa            5.006    5.0  5.8  4.3  0.352490
# versicolor        5.936    5.9  7.0  4.9  0.516171
# virginica         6.588    6.5  7.9  4.9  0.635880

# %%
grouped_agg = df.groupby('species').agg({'sepal_width':['mean','median','max','min','std']})

# %%
grouped_agg
# Out:
#            sepal_width
#                   mean median  max  min       std
# species
# setosa           3.418    3.4  4.4  2.3  0.381024
# versicolor       2.770    2.8  3.4  2.0  0.313798
# virginica        2.974    3.0  3.8  2.2  0.322497

# %%
grouped_agg = df.groupby('species').agg({'petal_length':['mean','median','max','min','std']})

# %%
grouped_agg
# Out:
#            petal_length
#                    mean median  max  min       std
# species
# setosa            1.464   1.50  1.9  1.0  0.173511
# versicolor        4.260   4.35  5.1  3.0  0.469911
# virginica         5.552   5.55  6.9  4.5  0.551895

# %%
grouped_agg = df.groupby('species').agg({'petal_width':['mean','median','max','min','std']})

# %%
grouped_agg
# Out:
#            petal_width
#                   mean median  max  min       std
# species
# setosa           0.244    0.2  0.6  0.1  0.107210
# versicolor       1.326    1.3  1.8  1.0  0.197753
# virginica        2.026    2.0  2.5  1.4  0.274650

# %%
loan
# Out:
#                                     Loan ID  \
# 0      f738779f-c726-40dc-92cf-689d73af533d
# 1      6dcc0947-164d-476c-a1de-3ae7283dde0a
# 2      f7744d01-894b-49c3-8777-fc6431a2cff1
# 3      83721ffb-b99a-4a0f-aea5-ef472a138b41
# 4      08f3789f-5714-4b10-929d-e1527ab5e5a3
# ...                                     ...
# 10348                                   NaN
# 10349                                   NaN
# 10350                                   NaN
# 10351                                   NaN
# 10352                                   NaN
#
#                                 Customer ID  Current Loan Amount        Term  \
# 0      ded0b3c3-6bf4-4091-8726-47039f2c1b90             611314.0  Short Term
# 1      1630e6e3-34e3-461a-8fda-09297d3140c8             266662.0  Short Term
# 2      2c60938b-ad2b-4702-804d-eeca43949c52             153494.0  Short Term
# 3      12116614-2f3c-4d16-ad34-d92883718806             176242.0  Short Term
# ...

# %%
loan.dtypes
# Out:
# Loan ID                          object
# Customer ID                      object
# Current Loan Amount             float64
# Term                             object
# Credit Score                    float64
# Annual Income                   float64
# Years in current job             object
# Home Ownership                   object
# Purpose                          object
# Monthly Debt                    float64
# Years of Credit History         float64
# Months since last delinquent    float64
# Number of Open Accounts         float64
# Number of Credit Problems       float64
# Current Credit Balance          float64
# Maximum Open Credit             float64
# Bankruptcies                    float64
# Tax Liens                       float64
# dtype: object

# %%
loan.isnull()
# Out:
#        Loan ID  Customer ID  Current Loan Amount   Term  Credit Score  \
# 0        False        False                False  False         False
# 1        False        False                False  False         False
# 2        False        False                False  False         False
# 3        False        False                False  False         False
# 4        False        False                False  False         False
# ...        ...          ...                  ...    ...           ...
# 10348     True         True                 True   True          True
# 10349     True         True                 True   True          True
# 10350     True         True                 True   True          True
# 10351     True         True                 True   True          True
# 10352     True         True                 True   True          True
#
#        Annual Income  Years in current job  Home Ownership  Purpose  \
# ...

# %%
loan.isnull().sum()
# Out:
# Loan ID                          353
# Customer ID                      353
# Current Loan Amount              353
# Term                             353
# Credit Score                    2334
# Annual Income                   2334
# Years in current job             780
# Home Ownership                   353
# Purpose                          353
# Monthly Debt                     353
# Years of Credit History          353
# Months since last delinquent    5659
# Number of Open Accounts          353
# Number of Credit Problems        353
# Current Credit Balance           353
# Maximum Open Credit              353
# Bankruptcies                     375
# Tax Liens                        354
# dtype: int64

# %%
loan.ffill()
# Out:
#                                     Loan ID  \
# 0      f738779f-c726-40dc-92cf-689d73af533d
# 1      6dcc0947-164d-476c-a1de-3ae7283dde0a
# 2      f7744d01-894b-49c3-8777-fc6431a2cff1
# 3      83721ffb-b99a-4a0f-aea5-ef472a138b41
# 4      08f3789f-5714-4b10-929d-e1527ab5e5a3
# ...                                     ...
# 10348  14f94b64-26c4-48fd-b916-1388d7adcc1d
# 10349  14f94b64-26c4-48fd-b916-1388d7adcc1d
# 10350  14f94b64-26c4-48fd-b916-1388d7adcc1d
# 10351  14f94b64-26c4-48fd-b916-1388d7adcc1d
# 10352  14f94b64-26c4-48fd-b916-1388d7adcc1d
#
#                                 Customer ID  Current Loan Amount        Term  \
# 0      ded0b3c3-6bf4-4091-8726-47039f2c1b90             611314.0  Short Term
# 1      1630e6e3-34e3-461a-8fda-09297d3140c8             266662.0  Short Term
# 2      2c60938b-ad2b-4702-804d-eeca43949c52             153494.0  Short Term
# 3      12116614-2f3c-4d16-ad34-d92883718806             176242.0  Short Term
# ...

# %%
Group_agg = loan.groupby('Term').agg({'Annual Income':['mean','median','max','min','std']})

# %%
Group_agg
# Out:
#            Annual Income
#                     mean     median         max       min            std
# Term
# Long Term   1.492479e+06  1322419.0   9434450.0  116603.0  803041.353357
# Short Term  1.322023e+06  1128001.5  17815350.0   81092.0  888118.552054

# %%
Group_agg = loan.groupby('Purpose').agg({'Annual Income':['mean','median','max','min','std']})

# %%
Group_agg
# Out:
#                      Annual Income                                    \
#                               mean     median         max        min
# Purpose
# Business Loan         1.748359e+06  1359659.0   9338880.0   191463.0
# Buy House             1.416811e+06   982765.5   7677501.0   352906.0
# Buy a Car             1.145025e+06   991724.0   3743171.0   259407.0
# Debt Consolidation    1.345394e+06  1165080.0  17815350.0   152114.0
# Educational Expenses  8.685122e+05   766498.0   2018085.0    81092.0
# Home Improvements     1.624465e+06  1375809.0   8526364.0   309757.0
# Medical Bills         1.285849e+06  1100223.5   6713460.0   226176.0
# Other                 1.397080e+06  1135098.0  16244088.0   130150.0
# Take a Trip           1.140087e+06  1058471.0   3371094.0   514045.0
# major_purchase        1.534124e+06  1100233.0  12574770.0   375364.0
# moving                9.461753e+05   735613.5   1780452.0   468635.0
# ...

# %%
Group_agg = loan.groupby('Purpose').agg({'Credit Score':['mean','median','max','min','std']})

# %%
Group_agg
# Out:
#                      Credit Score
#                              mean median     max    min          std
# Purpose
# Business Loan         1221.547445  715.0  7480.0  601.0  1752.687717
# Buy House              706.892857  712.5   750.0  608.0    34.004641
# Buy a Car              958.008850  732.0  7510.0  595.0  1227.573678
# Debt Consolidation    1076.101477  725.0  7500.0  585.0  1473.754998
# Educational Expenses   712.583333  716.5   747.0  662.0    23.043273
# Home Improvements     1101.853191  726.0  7450.0  595.0  1532.438440
# Medical Bills          967.990196  719.0  7360.0  646.0  1265.979678
# Other                 1078.979675  724.0  7480.0  610.0  1473.733921
# Take a Trip            912.696970  708.0  7450.0  674.0  1173.727569
# major_purchase        1137.116279  734.0  7050.0  640.0  1548.951707
# moving                1960.600000  707.5  7020.0  621.0  2653.575039
# other                 1110.381779  714.0  7490.0  600.0  1527.529531
# ...
